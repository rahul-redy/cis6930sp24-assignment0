# %%
import urllib.request

def fetchincidents(url):
    # Set a user-agent to avoid server rejection
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

    try:
        # Open the URL and read the data
        with urllib.request.urlopen(urllib.request.Request(url, headers=headers)) as response:
            incident_data = response.read()
            return incident_data
    except Exception as e:
        print(f"Error downloading data: {e}")
        return None

# Test the download function
url = "https://www.normanok.gov/sites/default/files/documents/2024-01/2024-01-01_daily_incident_summary.pdf"
incident_data = fetchincidents(url)

# Save the downloaded PDF to a local file
pdf_file_path = "downloaded_incident_summary.pdf"
with open(pdf_file_path, "wb") as pdf_file:
    pdf_file.write(incident_data)
# Out:
# Data downloaded successfully.

# %%
reader = PyPDF2.PdfReader("/Users/rahulreddy/Desktop/DE/downloaded_incident_summary.pdf")
page = reader.pages[0]
print(page.extract_text()) # Shows the extracted text
# Out:
# Date / Time Incident Number Location Nature Incident ORI
# 1/1/2024 0:01 2024-00000001 3603 N FLOOD AVE Traffic Stop OK0140200
# 1/1/2024 0:03 2024-00000001 226 CINDY AVE Chest Pain 14005
# 1/1/2024 0:03 2024-00000001 226 CINDY AVE Sick Person EMSSTAT
# 1/1/2024 0:04 2024-00000002 E MAIN ST / N JONES AVE Traffic Stop OK0140200
# 1/1/2024 0:06 2024-00000003 W ROCK CREEK RD / N FLOOD AVE Motorist Assist OK0140200
# 1/1/2024 0:07 2024-00000005 2001 VANESSA DR Burglary OK0140200
# 1/1/2024 0:11 2024-00000017 2817 DEVONSHIRE DR Shots Heard OK0140200
# 1/1/2024 0:12 2024-00000008 2118 W LINDSEY ST Alarm OK0140200
# 1/1/2024 0:14 2024-00000006 2501 CONFERENCE DR Disturbance/Domestic OK0140200
# 1/1/2024 0:16 2024-00000002 1201 E LINDSEY ST Fire Dumpster 14005
# 1/1/2024 0:16 2024-00000007 W ROBINSON ST / STUBBEMAN AVE Traffic Stop OK0140200
# 1/1/2024 0:21 2024-00000009 CHILLMARK DR / MONTILLA CT Traffic Stop OK0140200
# 1/1/2024 0:25 2024-00000022 156TH AVE NE / E INDIAN HILLS RD Shots Heard OK0140200
# 1/1/2024 0:25 2024-00000010 2300 MERIDIAN DR Disturbance/Domestic OK0140200
# 1/1/2024 0:29 2024-00000002 222 BULL RUN ST Shooting Stabbing Penetrating EMSSTAT
# 1/1/2024 0:29 2024-00000003 222 BULL RUN ST Shooting Stabbing Penetrating 14005NORMAN POLICE DEPARTMENT
# Daily Incident Summary (Public)

# %%
import re
import PyPDF2

def extractincidents(incident_data):
    # Create a PDF reader object
    pdf_reader = PyPDF2.PdfReader(incident_data)

    # Initialize an empty list to store extracted incidents
    incidents_list = []

    # Iterate through each page of the PDF
    for page_num in range(len(pdf_reader.pages)):
        # Get the text content of the current page
        page = pdf_reader.pages[page_num]
        page_text = page.extract_text()

        # Use regular expressions to extract relevant information
        pattern = re.compile(r'(\d{1,2}/\d{1,2}/\d{4} \d{1,2}:\d{2}) (\d{4}-\d+) (\S+ \S+ \S+) ([^\n]+) (\S+)')

        # Search for patterns in the page text
        matches = pattern.findall(page_text)

        # Process matches and skip empty rows
        for match in matches:
            if match[0] and match[1] and match[2] and match[3] and match[4]:
                incident = {
                    'Date/Time': match[0],
                    'Incident Number': match[1],
                    'Location': match[2],
                    'Nature': match[3],
                    'Incident ORI': match[4]
                }
                incidents_list.append(incident)

    return incidents_list

# Example usage:
incidents_data = extractincidents('/Users/rahulreddy/Desktop/DE/downloaded_incident_summary.pdf')
print(incidents_data)
# Out:
# [{'Date/Time': '1/1/2024 0:01', 'Incident Number': '2024-00000001', 'Location': '3603 N FLOOD', 'Nature': 'AVE Traffic Stop', 'Incident ORI': 'OK0140200'}, {'Date/Time': '1/1/2024 0:03', 'Incident Number': '2024-00000001', 'Location': '226 CINDY AVE', 'Nature': 'Chest Pain', 'Incident ORI': '14005'}, {'Date/Time': '1/1/2024 0:03', 'Incident Number': '2024-00000001', 'Location': '226 CINDY AVE', 'Nature': 'Sick Person', 'Incident ORI': 'EMSSTAT'}, {'Date/Time': '1/1/2024 0:04', 'Incident Number': '2024-00000002', 'Location': 'E MAIN ST', 'Nature': '/ N JONES AVE Traffic Stop', 'Incident ORI': 'OK0140200'}, {'Date/Time': '1/1/2024 0:06', 'Incident Number': '2024-00000003', 'Location': 'W ROCK CREEK', 'Nature': 'RD / N FLOOD AVE Motorist Assist', 'Incident ORI': 'OK0140200'}, {'Date/Time': '1/1/2024 0:07', 'Incident Number': '2024-00000005', 'Location': '2001 VANESSA DR', 'Nature': 'Burglary', 'Incident ORI': 'OK0140200'}, {'Date/Time': '1/1/2024 0:11', 'Incident Number': '2024-00000017', 'Location': '2817 DEVONSHIRE DR', 'Nature': 'Shots Heard', 'Incident ORI': 'OK0140200'}, {'Date/Time': '1/1/2024 0:12', 'Incident Number': '2024-00000008', 'Location': '2118 W LINDSEY', 'Nature': 'ST Alarm', 'Incident ORI': 'OK0140200'}, {'Date/Time': '1/1/2024 0:14', 'Incident Number': '2024-00000006', 'Location': '2501 CONFERENCE DR', 'Nature': 'Disturbance/Domestic', 'Incident ORI': 'OK0140200'}, {'Date/Time': '1/1/2024 0:16', 'Incident Number': '2024-00000002', 'Location': '1201 E LINDSEY', 'Nature': 'ST Fire Dumpster', 'Incident ORI': '14005'}, {'Date/Time': '1/1/2024 0:16', 'Incident Number': '2024-00000007', 'Location': 'W ROBINSON ST', 'Nature': '/ STUBBEMAN AVE Traffic Stop', 'Incident ORI': 'OK0140200'}, {'Date/Time': '1/1/2024 0:21', 'Incident Number': '2024-00000009', 'Location': 'CHILLMARK DR /', 'Nature': 'MONTILLA CT Traffic Stop', 'Incident ORI': 'OK0140200'}, {'Date/Time': '1/1/2024 0:25', 'Incident Number': '2024-00000022', 'Location': '156TH AVE NE', 'Nature': '/ E INDIAN HILLS RD Shots Heard', 'Incident ORI': 'OK0140200'}, {'Date/Time': '1/1/2024 0:25', 'Incident Number': '2024-00000010', 'Location': '2300 MERIDIAN DR', 'Nature': 'Disturbance/Domestic', 'Incident ORI': 'OK0140200'}, {'Date/Time': '1/1/2024 0:29', 'Incident Number': '2024-00000002', 'Location': '222 BULL RUN', 'Nature': 'ST Shooting Stabbing Penetrating', 'Incident ORI': 'EMSSTAT'}, {'Date/Time': '1/1/2024 0:29', 'Incident Number': '2024-00000003', 'Location': '222 BULL RUN', 'Nature': 'ST Shooting Stabbing Penetrating 14005NORMAN POLICE', 'Incident ORI': 'DEPARTMENT'}, {'Date/Time': '1/1/2024 0:29', 'Incident Number': '2024-00000011', 'Location': '222 BULL RUN', 'Nature': 'ST Shooting', 'Incident ORI': 'OK0140200'}, {'Date/Time': '1/1/2024 0:41', 'Incident Number': '2024-00000004', 'Location': '901 N PORTER', 'Nature': 'AVE Transfer/Interfacility', 'Incident ORI': 'EMSSTAT'}, {'Date/Time': '1/1/2024 0:47', 'Incident Number': '2024-00000013', 'Location': '1135 E BROOKS', 'Nature': 'ST Disturbance/Domestic', 'Incident ORI': 'OK0140200'}, {'Date/Time': '1/1/2024 0:48', 'Incident Number': '2024-00000015', 'Location': '1147 BILOXI DR', 'Nature': 'Suspicious', 'Incident ORI': 'OK0140200'}, {'Date/Time': '1/1/2024 0:50', 'Incident Number': '2024-00000005', 'Location': '2000 ANN BRANDEN', 'Nature': 'BLVD Transfer/Interfacility', 'Incident ORI': 'EMSSTAT'}, {'Date/Time': '1/1/2024 0:53', 'Incident Number': '2024-00000012', 'Location': 'E GRAY ST', 'Nature': '/ N CRAWFORD AVE Suspicious', 'Incident ORI': 'OK0140200'}, {'Date/Time': '1/1/2024 0:53', 'Incident Number': '2024-00000014', 'Location': 'E GRAY ST', 'Nature': '/ N CRAWFORD AVE Traffic Stop', 'Incident ORI': 'OK0140200'}, {'Date/Time': '1/1/2024 0:54', 'Incident Number': '2024-00000003', 'Location': '2550 W FRANKLIN', 'Nature': 'RD Breathing Problems', 'Incident ORI': 'EMSSTAT'}, {'Date/Time': '1/1/2024 0:54', 'Incident Number': '2024-00000004', 'Location': '2550 W FRANKLIN', 'Nature': 'RD Breathing Problems',  ...

# %%
import os
import sqlite3

def createdb():
    # Ensure 'resources' directory exists
    if not os.path.exists('resources'):
        os.makedirs('resources')

    # Connect to the database or create if it doesn't exist
    conn = sqlite3.connect('resources/normanpd.db')
    
    # Create a cursor object to execute SQL queries
    cursor = conn.cursor()

    # Execute the SQL query to create the incidents table
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS incidents (
            incident_time TEXT,
            incident_number TEXT,
            incident_location TEXT,
            nature TEXT,
            incident_ori TEXT
        )
    ''')

    # Commit the changes and close the connection
    conn.commit()
    conn.close()

# Example usage:
createdb()

# %%
import sqlite3

def populatedb(db, incidents):
    # Connect to the database
    conn = sqlite3.connect(db)
    
    # Create a cursor object
    cursor = conn.cursor()

    # Iterate over incidents and insert into the database
    for incident in incidents:
        cursor.execute('''
            INSERT INTO incidents 
            (incident_time, incident_number, incident_location, nature, incident_ori)
            VALUES (?, ?, ?, ?, ?)
        ''', (incident['Date/Time'], incident['Incident Number'], incident['Location'], incident['Nature'], incident['Incident ORI']))

    # Commit the changes and close the connection
    conn.commit()
    conn.close()

def status(db):
    # Connect to the database
    conn = sqlite3.connect(db)
    
    # Create a cursor object
    cursor = conn.cursor()

    # Execute a query to get the nature and count of each incident
    cursor.execute('''
        SELECT nature, COUNT(*) as count 
        FROM incidents 
        GROUP BY nature 
        ORDER BY count DESC, nature
    ''')

    # Fetch all rows and print the status
    rows = cursor.fetchall()
    for row in rows:
        print(f"{row[0]}|{row[1]}")

    # Close the connection
    conn.close()

# %%
populatedb('resources/normanpd.db', incidents_data)

# %%
status('resources/normanpd.db')
# Out:
# ST Traffic Stop|50
# AVE Traffic Stop|30
# Sick Person|22
# Disturbance/Domestic|20
# AVE Transfer/Interfacility|16
# BLVD Transfer/Interfacility|14
# Contact a Subject|14
# Falls|12
# Larceny|12
# Suspicious|12
# Transfer/Interfacility|12
# AVE Trespassing|10
# Chest Pain|10
# HWY 9 HWY Traffic Stop|10
# ST Disturbance/Domestic|10
# Fire Commercial|8
# Public Assist|8
# ST Abdominal Pains/Problems|8
# ST Alarm|8
# ST Falls|8
# Shots Heard|8
# Traffic Stop|8
# 911 Call Nature Unknown|6
# Alarm|6
# SE Traffic Stop|6
# ST Contact a Subject|6
# ST Sick Person|6
# / E STATE HWY 9 HWY Breathing Problems|4
# / W LINDSEY ST Traffic Stop|4
# / W ROBINSON ST Traffic Stop|4
# AVE Fire Controlled Burn|4
# Abdominal Pains/Problems|4
# Assault EMS Needed|4
# BLVD Chest Pain|4
# Breathing Problems|4
# Check Area|4
# DR Breathing Problems|4
# DR Shots Heard|4
# DR Sick Person|4
# DR Traffic Stop|4
# DR Welfare Check|4
# Diabetic Problems|4
# Extra Patrol|4
# Follow Up|4
# LANE RD Unknown Problem/Man Down|4
# Medical Call Pd Requested|4
# NE Assault EMS Needed|4
# NE Traffic Stop|4
# RD Breathing Problems|4
# RD Stroke|4
# RD Transfer/Interfacility|4
# SE Breathing Problems|4
# SE Contact a Subject|4
# ST Found Item|4
# ST Stroke|4
# ST Suspicious|4
# Traumatic Injury|4
# Unconscious/Fainting|4
# Vandalism|4
# Welfare Check|4
# / CLASSEN BLVD Traffic Stop|2
# / DAKOTA ST Traffic Stop|2
# / DEREK LN Hit and Run|2
# / E APACHE ST Traffic Stop|2
# / E HAYFIELD RD Animal Livestock|2
# / E INDIAN HILLS RD Shots Heard|2
# / E LINDSEY ST Check Area|2
# / E STATE HWY 9 HWY Traffic Stop|2
# / JEAN MARIE DR Traffic Stop|2
# / LEOPARD LILY DR Hit and Run|2
# / LINDSEY PLAZA DR Traffic Stop|2
# / N CRAWFORD AVE Suspicious|2
# / N CRAWFORD AVE Traffic Stop|2
# / N FLOOD AVE Traffic Stop|2
# / N JONES AVE Traffic Stop|2
# / N PETERS AVE Contact a Subject|2
# / N PORTER AVE Suspicious|2
# / S BERRY RD Traffic Stop|2
# / S WEBSTER AVE Traffic Stop|2
# / STUBBEMAN AVE Traffic Stop|2
# / W SYMMES ST Traffic Stop|2
# / W TECUMSEH RD Hit and Run|2
# 12TH AVE SE Motorist Assist|2
# 24TH AVE SW Traffic Stop|2
# 9 HWY / 168TH AVE NE Fire Grass|2
# 9 HWY / W IMHOFF RD Welfare Check|2
# ALAMEDA ST Traffic Stop|2
# AVE Check Area|2
# AVE Disturbance/Domestic|2
# AVE Escort/Transport|2
# AVE Mutual Aid|2
# Animal Complaint|2
# Assault|2
# Assist Police|2
# BLVD Assist Fire|2
# BLVD Special Assignment|2
# Burglary|2
# CLASSEN CIR Motorist Assist|2
# CT Alarm|2
# DR Check Area|2
# DR Contact a Subject|2
# DR Follow Up|2
# DR Fraud|2
# DR Harassment / Threats Report|2
# DR Motorist Assist|2
# E BROOKS ST Traffic Stop|2
# Fire Smoke Investigation|2
# Fireworks|2
# Fraud|2
# HWY 9 HWY Suspicious|2
# Harassment / Threats Report|2
# Hit and Run|2
# Item Assignment|2
# LANE RD Public Assist|2
# MONTILLA CT Traffic Stop|2
# Motorist Assist|2
# NE Cardiac Respritory Arrest|2
# NE Check Area|2
# NE Medical Call Pd Requested|2
# NE Trespassing|2
# NE Unconscious/Fainting|2
# NW Fire Alarm|2
# PKWY Welfare Check|2
# Person|2
# RD / N FLOOD AVE Motorist Assist|2
# RD Mutual Aid|2
# RD Traffic Stop|2
# Runaway or Lost Child|2
# SE Reckless Driving|2
# SE Warrant Service|2
# ST 911 Call Nature Unknown|2
# ST Assault|2
# ST Check Area|2
# ST Civil Standby|2
# ST Fight|2
# ST Fire Dumpster|2
# ST Follow Up|2
# ST Harassment / Threats Report|2
# ST Larceny|2
# ST Medical Call Pd Requested|2
# ST Molesting|2
# ST Open Door/Premises Check|2
# ST Public Intoxication|2
# ST Shooting|2
# ST Shooting Stabbing Penetrating|2
# ST Shooting Stabbing Penetrating 14005NORMAN POLICE|2
# ST Unconscious/Fainting|2
# ST Welfare Check|2
# SW Alarm|2
# TROUT AVE Noise Complaint|2
# W BOYD ST Traffic Stop|2
# W TECUMSEH RD MVA Non Injury|2
